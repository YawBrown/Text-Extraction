# %% [markdown]
# PREPARATION

# %%
import requests

# %%
r = requests.get("https://raw.githubusercontent.com/tesseract-ocr/tessdata/4.00/ind.traineddata", stream = True)

with open("/usr/share/tesseract-ocr/4.00/tessdata/ind.traineddata", "wb") as file:
    for block in r.iter_content(chunk_size = 1024):
         if block:
             file.write(block)

# %%
! apt install tesseract-ocr libtesseract-dev libmagickwand-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libtesseract-dev is already the newest version (4.1.1-2build2).
# tesseract-ocr is already the newest version (4.1.1-2build2).
# libmagickwand-dev is already the newest version (8:6.9.10.23+dfsg-2.1ubuntu11.7).
# 0 upgraded, 0 newly installed, 0 to remove and 13 not upgraded.

# %%
! pip install pytesseract wand opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from PIL import Image
import pytesseract
import cv2
import numpy as np
from pytesseract import Output
import re

# %%
image = Image.open('FinalTest.JPG')
image = image.resize((300,300))
image.save('resized.png')
image
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x7FD2F40DFB20>

# %%
image=cv2.imread('resized.png')

# %%
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
gray = get_grayscale(image)
Image.fromarray(gray)
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x7FD2F40DDDE0>

# %%
cv2.imwrite("gray.png", gray)
# Out:
# True

# %%
T = Image.open("gray.png")

# %%
custom_config = r'-l eng --oem 3 --psm 6'
text = pytesseract.image_to_string(T,config=custom_config)
print(text)
# Out:
# | AM A CHILD OF GOD

# %%
#gray=cv2.imread('gray.png')

# %%
# def remove_noise(image):
#     return cv2.medianBlur(image,5)
# noiseless = remove_noise(gray)
# Image.fromarray(noiseless)

# %%
# cv2.imwrite("postgrayblur.png",noiseless)
# Out:
# True

# %%
# im=cv2.imread('postgrayblur.png')

# %%
# a, b, c = cv2.split(im)

# %%
# Image.fromarray(a)

# %%
# #thresholding
# def thresholding(image):
#     return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
# thresh = thresholding(a)
# Image.fromarray(thresh)

# %%
# cv2.imwrite('threshgrayblur.png',thresh)
# Out:
# True

# %%
# Final=Image.open("threshgrayblur.png")

# %%
# custom_config = r'-l eng --oem 3 --psm 6'
# text = pytesseract.image_to_string(Final,config=custom_config)
# print(text)
